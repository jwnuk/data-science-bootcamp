# %% [markdown]
# # Import danych & normalizacja

# %%
import pandas as pd

df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# Normalizacja string -> boolean
df = df.replace({ 'Yes': True })
df = df.replace({ 'No': False })

# Normalizacja string -> enum (BusinessTravel)
df = df.replace({ 'Non-Travel': 0 })
df = df.replace({ 'Travel_Rarely': 1 })
df = df.replace({ 'Travel_Frequently': 2 })

# Normalizacja string -> enum (Department)
df['Department'] = df['Department'].replace({ 'Sales': 0 })
df = df['Department'].replace({ 'Research & Development': 1 })
df = df['Department'].replace({ 'Human Resources': 2 })

# Usunięcie kolumn, które dla każdego rekordu posiadają niezmienną, stałą wartość (1, 80, ID, 1)
df = df.drop(['EmployeeCount', 'StandardHours', 'EmployeeNumber', 'Over18'], 1) # y-axis

# Enumeracja nazw kolumn
column_count = 0
for column in df:
    print(column)
    column_count += 1
  
print(column_count)

df.to_csv('dataset-normalized.csv')
# Out:
# Age
# Attrition
# BusinessTravel
# DailyRate
# Department
# DistanceFromHome
# Education
# EducationField
# EnvironmentSatisfaction
# Gender
# HourlyRate
# JobInvolvement
# JobLevel
# JobRole
# JobSatisfaction
# MaritalStatus
# MonthlyIncome
# MonthlyRate
# NumCompaniesWorked
# OverTime
# PercentSalaryHike
# PerformanceRating
# RelationshipSatisfaction
# StockOptionLevel
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager
# 31

# %% [markdown]
# # Opis danych

# %%
df.describe()['DistanceFromHome']
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %% [markdown]
# # Korelacja

# %%
corr_table = df.corr()

# corr_table = corr_table.drop(['EmployeeCount', 'StandardHours'], 0) # x-axis
# corr_table = corr_table.drop(['EmployeeCount', 'StandardHours'], 1) # y-axis

def corr_color(val):
    if abs(val) == 1:
        color = '#666'
    elif abs(val) > 0.8:
        color = '#9d0208'
    elif abs(val) > 0.5:
        color = '#e85d04'
    elif abs(val) > 0.3:
        color = '#f48c06'
    else:
        color = 'black'
    return 'color: %s' % color

s = corr_table.style.applymap(corr_color).set_caption('Korelacje między danymi pracowników')

s
# Out:
# <style  type="text/css" >
#     #T_78216a8e_d438_11eb_b97c_acde48001122row0_col0 {
#             color:  #666;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col1 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col2 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col3 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col4 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col5 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col6 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col7 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col8 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col9 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col10 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col11 {
#             color:  #e85d04;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col12 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col13 {
#             color:  #f48c06;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col14 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col15 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col16 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col17 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col18 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col19 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col20 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col21 {
#             color:  #e85d04;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col22 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col23 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col24 {
#             color:  #f48c06;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col25 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col26 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row0_col27 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col0 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col1 {
#             color:  #666;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col2 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col3 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col4 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col5 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col6 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col7 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col8 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col9 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col10 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col11 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col12 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col13 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col14 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col15 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col16 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col17 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col18 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col19 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col20 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col21 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col22 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col23 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col24 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col25 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col26 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row1_col27 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col0 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col1 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col2 {
#             color:  #666;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col3 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col4 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col5 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col6 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col7 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col8 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col9 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col10 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col11 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col12 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col13 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col14 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col15 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col16 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col17 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col18 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col19 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col20 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col21 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col22 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col23 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col24 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col25 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col26 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row2_col27 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row3_col0 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row3_col1 {
#             color:  black;
#         }    #T_78216a8e_d438_11eb_b97c_acde48001122row3_col2 {
#             color:  black;
