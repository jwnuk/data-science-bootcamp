# %%
import sys

# %%
sys.path.append(r'./../../misc')

# %%
from matplotlib import pyplot
import pandas as pd

# %%
import data_preparation as prep

# %%
df = prep.df

# %%
df_corr = prep.df_corr

# %% [markdown]
# ## Kolumny do analizy - zarobki:
# - 'DailyRate'
# - 'HourlyRate'
# - 'MonthlyIncome'
# - 'MonthlyRate'
# - 'PercentSalaryHike'
#
# ## Kolumny do analizy - zadowolenie:
# - 'EnvironmentSatisfaction'
# - 'JobSatisfaction'
# - 'RelationshipSatisfaction'

# %%
df_salary = df[['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'PercentSalaryHike', 'EnvironmentSatisfaction', 'JobSatisfaction', 'RelationshipSatisfaction']]
df_salary
# Out:
#       DailyRate  HourlyRate  MonthlyIncome  MonthlyRate  PercentSalaryHike  \
# 0          1102          94           5993        19479                 11
# 1           279          61           5130        24907                 23
# 2          1373          92           2090         2396                 15
# 3          1392          56           2909        23159                 11
# 4           591          40           3468        16632                 12
# ...         ...         ...            ...          ...                ...
# 1465        884          41           2571        12290                 17
# 1466        613          42           9991        21457                 15
# 1467        155          87           6142         5174                 20
# 1468       1023          63           5390        13243                 14
# 1469        628          82           4404        10228                 12
#
# ...

# %%
col_names = list(df_salary.columns)

for column in col_names:
    prep.print_values(df_salary, column)
# Out:
# 691     6
# 1082    5
# 329     5
# 1329    5
# 530     5
#        ..
# 897     1
# 891     1
# 889     1
# 888     1
# 102     1
# Name: DailyRate, Length: 886, dtype: int64
#
# 66    29
# 42    28
# 98    28
# 48    28
# 84    28
#       ..
# 31    15
# 68    14
# 53    14
# 38    13
# 34    12
# Name: HourlyRate, Length: 71, dtype: int64
#
# 2342     4
# 5562     3
# 2741     3
# 2451     3
# 2610     3
#         ..
# 5381     1
# 13577    1
# 12965    1
# 3339     1
# 14336    1
# Name: MonthlyIncome, Length: 1349, dtype: int64
#
# 4223     3
# 9150     3
# 6670     2
# 7324     2
# 4658     2
#         ..
# 11585    1
# 15682    1
# 3395     1
# 9541     1
# 8192     1
# Name: MonthlyRate, Length: 1427, dtype: int64
#
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: PercentSalaryHike, dtype: int64
#
# 3    453
# 4    446
# 2    287
# ...

# %% [markdown]
# ## Analiza zarobków - zadowolenie ze środowiska

# %%
df_salary_env1 = df_salary[df_salary['EnvironmentSatisfaction'] == 1]
df_salary_env2 = df_salary[df_salary['EnvironmentSatisfaction'] == 2]
df_salary_env3 = df_salary[df_salary['EnvironmentSatisfaction'] == 3]
df_salary_env4 = df_salary[df_salary['EnvironmentSatisfaction'] == 4]

# %%
df_salary_env1.hist()
df_salary_env2.hist()
df_salary_env3.hist()
df_salary_env4.hist()
# Out:
# array([[<AxesSubplot:title={'center':'DailyRate'}>,
#         <AxesSubplot:title={'center':'HourlyRate'}>,
#         <AxesSubplot:title={'center':'MonthlyIncome'}>],
#        [<AxesSubplot:title={'center':'MonthlyRate'}>,
#         <AxesSubplot:title={'center':'PercentSalaryHike'}>,
#         <AxesSubplot:title={'center':'EnvironmentSatisfaction'}>],
#        [<AxesSubplot:title={'center':'JobSatisfaction'}>,
#         <AxesSubplot:title={'center':'RelationshipSatisfaction'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_salary_env1.corr().style.applymap(prep.corr_color)
# Out:
# <style  type="text/css" >
# #T_107e6c28_de91_11eb_827a_309c238a522arow0_col0,#T_107e6c28_de91_11eb_827a_309c238a522arow1_col1,#T_107e6c28_de91_11eb_827a_309c238a522arow2_col2,#T_107e6c28_de91_11eb_827a_309c238a522arow3_col3,#T_107e6c28_de91_11eb_827a_309c238a522arow4_col4,#T_107e6c28_de91_11eb_827a_309c238a522arow6_col6,#T_107e6c28_de91_11eb_827a_309c238a522arow7_col7{
#             color:  red;
# ...

# %%
df_salary_env2.corr().style.applymap(prep.corr_color)
# Out:
# <style  type="text/css" >
# #T_1da85847_de91_11eb_9fc8_309c238a522arow0_col0,#T_1da85847_de91_11eb_9fc8_309c238a522arow1_col1,#T_1da85847_de91_11eb_9fc8_309c238a522arow2_col2,#T_1da85847_de91_11eb_9fc8_309c238a522arow3_col3,#T_1da85847_de91_11eb_9fc8_309c238a522arow4_col4,#T_1da85847_de91_11eb_9fc8_309c238a522arow6_col6,#T_1da85847_de91_11eb_9fc8_309c238a522arow7_col7{
#             color:  red;
# ...

# %%
df_salary_env3.corr().style.applymap(prep.corr_color)
# Out:
# <style  type="text/css" >
# #T_1e3acac1_de91_11eb_a1ad_309c238a522arow0_col0,#T_1e3acac1_de91_11eb_a1ad_309c238a522arow1_col1,#T_1e3acac1_de91_11eb_a1ad_309c238a522arow2_col2,#T_1e3acac1_de91_11eb_a1ad_309c238a522arow3_col3,#T_1e3acac1_de91_11eb_a1ad_309c238a522arow4_col4,#T_1e3acac1_de91_11eb_a1ad_309c238a522arow6_col6,#T_1e3acac1_de91_11eb_a1ad_309c238a522arow7_col7{
#             color:  red;
# ...

# %%
df_salary_env4.corr().style.applymap(prep.corr_color)
# Out:
# <style  type="text/css" >
# #T_1e9b25a3_de91_11eb_96ae_309c238a522arow0_col0,#T_1e9b25a3_de91_11eb_96ae_309c238a522arow1_col1,#T_1e9b25a3_de91_11eb_96ae_309c238a522arow2_col2,#T_1e9b25a3_de91_11eb_96ae_309c238a522arow3_col3,#T_1e9b25a3_de91_11eb_96ae_309c238a522arow4_col4,#T_1e9b25a3_de91_11eb_96ae_309c238a522arow6_col6,#T_1e9b25a3_de91_11eb_96ae_309c238a522arow7_col7{
#             color:  red;
# ...

# %%
df_salary.groupby('EnvironmentSatisfaction').mean()
# Out:
#                           DailyRate  HourlyRate  MonthlyIncome   MonthlyRate  \
# EnvironmentSatisfaction
# 1                        794.894366   66.838028    6717.080986  14032.014085
# 2                        791.634146   66.940767    6283.728223  13719.519164
# 3                        804.260486   66.373068    6482.366446  14645.262693
# 4                        812.500000   64.123318    6528.511211  14536.690583
#
#                          PercentSalaryHike  JobSatisfaction  \
# EnvironmentSatisfaction
# 1                                15.348592         2.757042
# 2                                15.226481         2.721254
# 3                                15.337748         2.710817
# 4                                14.979821         2.733184
#
#                          RelationshipSatisfaction
# EnvironmentSatisfaction
# 1                                        2.718310
# 2                                        2.675958
# ...

# %%
df_salary.groupby('JobSatisfaction').mean()
# Out:
#                   DailyRate  HourlyRate  MonthlyIncome   MonthlyRate  \
# JobSatisfaction
# 1                782.505190   68.636678    6561.570934  14095.377163
# 2                771.675000   66.632143    6527.328571  14392.317857
# 3                835.500000   64.882353    6480.495475  14623.020362
# 4                802.069717   64.681917    6472.732026  14103.429194
#
#                  PercentSalaryHike  EnvironmentSatisfaction  \
# JobSatisfaction
# 1                        15.231834                 2.743945
# 2                        15.117857                 2.764286
# 3                        15.013575                 2.651584
# 4                        15.440087                 2.749455
#
#                  RelationshipSatisfaction
# JobSatisfaction
# 1                                2.730104
# 2                                2.735714
# 3                                2.696833
# 4                                2.701525

# %%
df_salary.groupby('RelationshipSatisfaction').mean()
# Out:
#                            DailyRate  HourlyRate  MonthlyIncome   MonthlyRate  \
# RelationshipSatisfaction
# 1                         797.130435   65.152174    6177.793478  14799.438406
# 2                         812.656766   67.587459    6596.983498  13712.881188
# 3                         787.762527   64.891068    6543.773420  14328.864924
# 4                         814.416667   66.236111    6601.296296  14406.631944
#
#                           PercentSalaryHike  EnvironmentSatisfaction  \
# RelationshipSatisfaction
# 1                                 15.463768                 2.655797
# 2                                 15.372937                 2.768977
# 3                                 15.047930                 2.749455
# 4                                 15.104167                 2.701389
#
#                           JobSatisfaction
# RelationshipSatisfaction
# 1                                2.721014
# 2                                2.749175
# ...
