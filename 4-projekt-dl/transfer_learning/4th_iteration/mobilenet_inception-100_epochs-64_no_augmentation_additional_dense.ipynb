# %% [markdown]
# # Trasfer learning model

# %%
# !pip install seaborn

# %%
import numpy as np
import os
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from sklearn.metrics import classification_report

# %% [markdown]
# ## Dataset

# %%
dataset_path = os.path.join('../../Brain Tumor Data Set')
dataset = tf.keras.utils.image_dataset_from_directory(dataset_path)

dataset
# Out:
# Found 4600 files belonging to 2 classes.
# <BatchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
class_names = np.array(dataset.class_names)
print(class_names)
# Out:
# ['Brain Tumor' 'Healthy']

# %% [markdown]
# ### Train - test split

# %%
ds_train = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset='training',
    seed=404,
    batch_size=64
)
# Out:
# Found 4600 files belonging to 2 classes.
# Using 3680 files for training.

# %%
ds_val = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset='validation',
    seed=404,
    batch_size=64
)
# Out:
# Found 4600 files belonging to 2 classes.
# Using 920 files for validation.

# %%
for image_batch, labels_batch in ds_train:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (64, 256, 256, 3)
# (64,)

# %% [markdown]
# ## Mobilenet_v2 - model without augmentation, with dense & dropout layer

# %%
input_shape = (224, 224, 3)

# %%
resizer = lambda x, y: (tf.image.resize(x, input_shape[:2]), y)

ds_train_reshaped = ds_train.map(resizer)
ds_val_reshaped = ds_val.map(resizer)

# %%
for image_batch, labels_batch in ds_train_reshaped:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
base_model = keras.applications.mobilenet_v2.MobileNetV2(
    weights='imagenet',
    input_shape=input_shape,
    include_top=False
)

base_model.trainable = False

model_1 = tf.keras.Sequential(
    [
        keras.layers.Input(input_shape, dtype=tf.float32),
        base_model,
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dense(320),
        keras.layers.Dropout(0.25, seed=404),
        keras.layers.Dense(64),
        keras.layers.Dropout(0.25, seed=404),
        keras.layers.Dense(1)
    ],
    name='mobilenet_with_2_dense_no_augmentation'
)

model_1.summary()
# Out:
# Model: "mobilenet_with_2_dense_no_augmentation"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 320)               409920
# _________________________________________________________________
# dropout (Dropout)            (None, 320)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                20544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,688,513
# Trainable params: 430,529
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model_1.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

# %%
epochs = 100
patience = 5

# %%
history_1 = model_1.fit(
    ds_train_reshaped,
    epochs=epochs,
    validation_data=ds_val_reshaped,
    callbacks=[keras.callbacks.EarlyStopping(patience=patience)]
)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 280s 5s/step - loss: 0.7789 - binary_accuracy: 0.7688 - val_loss: 0.2993 - val_binary_accuracy: 0.8793
# Epoch 2/100
# 58/58 [==============================] - 251s 4s/step - loss: 0.3223 - binary_accuracy: 0.8652 - val_loss: 0.2407 - val_binary_accuracy: 0.9065
# Epoch 3/100
# 58/58 [==============================] - 211s 4s/step - loss: 0.2716 - binary_accuracy: 0.8897 - val_loss: 0.2694 - val_binary_accuracy: 0.9000
# Epoch 4/100
# 58/58 [==============================] - 207s 4s/step - loss: 0.2491 - binary_accuracy: 0.9033 - val_loss: 0.2292 - val_binary_accuracy: 0.9130
# Epoch 5/100
# 58/58 [==============================] - 209s 4s/step - loss: 0.2522 - binary_accuracy: 0.8989 - val_loss: 0.3024 - val_binary_accuracy: 0.8946
# Epoch 6/100
# 58/58 [==============================] - 207s 4s/step - loss: 0.2775 - binary_accuracy: 0.8976 - val_loss: 0.1910 - val_binary_accuracy: 0.9250
# Epoch 7/100
# 58/58 [==============================] - 208s 4s/step - loss: 0.2073 - binary_accuracy: 0.9212 - val_loss: 0.2144 - val_binary_accuracy: 0.9011
# Epoch 8/100
# 58/58 [==============================] - 209s 4s/step - loss: 0.1915 - binary_accuracy: 0.9228 - val_loss: 0.2036 - val_binary_accuracy: 0.9228
# Epoch 9/100
# 58/58 [==============================] - 209s 4s/step - loss: 0.1791 - binary_accuracy: 0.9378 - val_loss: 0.1689 - val_binary_accuracy: 0.9380
# Epoch 10/100
# 58/58 [==============================] - 208s 4s/step - loss: 0.1830 - binary_accuracy: 0.9269 - val_loss: 0.1859 - val_binary_accuracy: 0.9315
# Epoch 11/100
# 58/58 [==============================] - 196s 3s/step - loss: 0.1776 - binary_accuracy: 0.9304 - val_loss: 0.2222 - val_binary_accuracy: 0.9261
# Epoch 12/100
# 58/58 [==============================] - 209s 4s/step - loss: 0.1651 - binary_accuracy: 0.9329 - val_loss: 0.1515 - val_binary_accuracy: 0.9391
# Epoch 13/100
# 58/58 [==============================] - 207s 4s/step - loss: 0.1245 - binary_accuracy: 0.9543 - val_loss: 0.1673 - val_binary_accuracy: 0.9272
# Epoch 14/100
# 58/58 [==============================] - 209s 4s/step - loss: 0.1374 - binary_accuracy: 0.9448 - val_loss: 0.1656 - val_binary_accuracy: 0.9435
# Epoch 15/100
# 58/58 [==============================] - 208s 4s/step - loss: 0.1136 - binary_accuracy: 0.9554 - val_loss: 0.2063 - val_binary_accuracy: 0.9370
# Epoch 16/100
# 58/58 [==============================] - 210s 4s/step - loss: 0.1032 - binary_accuracy: 0.9630 - val_loss: 0.1558 - val_binary_accuracy: 0.9478
# Epoch 17/100
# 58/58 [==============================] - 212s 4s/step - loss: 0.0958 - binary_accuracy: 0.9647 - val_loss: 0.1815 - val_binary_accuracy: 0.9207

# %%
history_1.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
plt.plot(history_1.history['loss'][1:])
plt.plot(history_1.history['val_loss'][1:])
plt.legend(['train', 'valid'])
plt.show();

# %%
plt.plot(history_1.history['binary_accuracy'][1:])
plt.plot(history_1.history['val_binary_accuracy'][1:])
plt.legend(['train', 'valid'])
plt.show();

# %% [markdown]
# ### Classification accuracy

# %%
x_val_1, y_val_1 = list(tfds.as_numpy(ds_val_reshaped))[0]
y_pred_1 = model_1.predict(x_val_1)
sum((y_pred_1[:, 0] > 0) == y_val_1) / len(y_val_1)
# Out:
# 0.921875

# %%
plt.figure(figsize=(16, 16))
plt.subplots_adjust(hspace=0.4, wspace=.2)

for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(x_val_1[i].astype('int32'))
    
    real_y = 'healthy' if y_val_1[i] == 1 else 'tumor'
    pred_y = 'healthy' if y_pred_1[i] > 0 else 'tumor'
    
    plt.title(f'Real class: {real_y}\n Prediction: {pred_y}')
    plt.axis('off')

plt.show();

# %%
y_pred_1_binary = [1 if y > 0 else 0 for y in y_pred_1]

# %%
cf = tf.math.confusion_matrix(y_val_1, y_pred_1_binary, dtype=tf.dtypes.int32)
sns.heatmap(cf, annot=True)
plt.xlabel('Predictions')
plt.ylabel('True values')
plt.show();

# %%
print(classification_report(y_val_1, y_pred_1_binary, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#  Brain Tumor       0.88      1.00      0.94        37
#      Healthy       1.00      0.81      0.90        27
#
#     accuracy                           0.92        64
#    macro avg       0.94      0.91      0.92        64
# weighted avg       0.93      0.92      0.92        64

# %% [markdown]
# ## Inception_v3 - model without augmentation, with dense & dropout layer

# %%
input_shape = (256, 256, 3)

# %%
base_model = keras.applications.inception_v3.InceptionV3(
    weights='imagenet',
    input_shape=input_shape,
    include_top=False
)

base_model.trainable = False

model_2 = tf.keras.Sequential(
    [
        keras.layers.Input(input_shape, dtype=tf.float32),
        base_model,
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dense(320),
        keras.layers.Dropout(0.25, seed=404),
        keras.layers.Dense(64),
        keras.layers.Dropout(0.25, seed=404),
        keras.layers.Dense(1)
    ],
    name='inception_with_2_dense_no_augmentation'
)

model_2.summary()
# Out:
# Model: "inception_with_2_dense_no_augmentation"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 6, 6, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 320)               655680
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 320)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                20544
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 22,479,073
# Trainable params: 676,289
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_2.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

# %%
epochs = 100
patience = 5

# %%
history_2 = model_2.fit(
    ds_train,
    epochs=epochs,
    validation_data=ds_val,
    callbacks=[keras.callbacks.EarlyStopping(patience=patience)]
)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 612s 10s/step - loss: 17.8355 - binary_accuracy: 0.5783 - val_loss: 2.1526 - val_binary_accuracy: 0.7609
# Epoch 2/100
# 58/58 [==============================] - 579s 10s/step - loss: 4.3777 - binary_accuracy: 0.6603 - val_loss: 4.9206 - val_binary_accuracy: 0.5630
# Epoch 3/100
# 58/58 [==============================] - 569s 10s/step - loss: 4.3254 - binary_accuracy: 0.6723 - val_loss: 1.7312 - val_binary_accuracy: 0.7500
# Epoch 4/100
# 58/58 [==============================] - 582s 10s/step - loss: 3.5214 - binary_accuracy: 0.7122 - val_loss: 1.0713 - val_binary_accuracy: 0.8533
# Epoch 5/100
# 58/58 [==============================] - 672s 12s/step - loss: 3.4464 - binary_accuracy: 0.7291 - val_loss: 2.0588 - val_binary_accuracy: 0.7500
# Epoch 6/100
# 58/58 [==============================] - 720s 12s/step - loss: 2.8259 - binary_accuracy: 0.7481 - val_loss: 3.2082 - val_binary_accuracy: 0.7391
# Epoch 7/100
# 58/58 [==============================] - 634s 11s/step - loss: 2.4628 - binary_accuracy: 0.7647 - val_loss: 1.6369 - val_binary_accuracy: 0.7924
# Epoch 8/100
# 58/58 [==============================] - 631s 11s/step - loss: 2.4088 - binary_accuracy: 0.7630 - val_loss: 1.0543 - val_binary_accuracy: 0.8522
# Epoch 9/100
# 58/58 [==============================] - 622s 11s/step - loss: 2.5789 - binary_accuracy: 0.7761 - val_loss: 2.2252 - val_binary_accuracy: 0.7978
# Epoch 10/100
# 58/58 [==============================] - 623s 11s/step - loss: 3.0355 - binary_accuracy: 0.7459 - val_loss: 1.0993 - val_binary_accuracy: 0.8413
# Epoch 11/100
# 58/58 [==============================] - 632s 11s/step - loss: 1.9779 - binary_accuracy: 0.7804 - val_loss: 1.2909 - val_binary_accuracy: 0.8022
# Epoch 12/100
# 58/58 [==============================] - 631s 11s/step - loss: 1.9340 - binary_accuracy: 0.7821 - val_loss: 0.6380 - val_binary_accuracy: 0.8793
# Epoch 13/100
# 58/58 [==============================] - 688s 12s/step - loss: 1.6789 - binary_accuracy: 0.7967 - val_loss: 0.6354 - val_binary_accuracy: 0.8837
# Epoch 14/100
# 58/58 [==============================] - 723s 12s/step - loss: 1.2975 - binary_accuracy: 0.8065 - val_loss: 0.7096 - val_binary_accuracy: 0.8772
# Epoch 15/100
# 58/58 [==============================] - 777s 13s/step - loss: 1.3349 - binary_accuracy: 0.8073 - val_loss: 1.1064 - val_binary_accuracy: 0.8293
# Epoch 16/100
# 58/58 [==============================] - 694s 12s/step - loss: 1.3023 - binary_accuracy: 0.8030 - val_loss: 0.5761 - val_binary_accuracy: 0.8804
# Epoch 17/100
# 58/58 [==============================] - 689s 12s/step - loss: 1.1430 - binary_accuracy: 0.8122 - val_loss: 0.5337 - val_binary_accuracy: 0.8946
# Epoch 18/100
# 58/58 [==============================] - 684s 12s/step - loss: 1.0934 - binary_accuracy: 0.8038 - val_loss: 0.5368 - val_binary_accuracy: 0.8793
# Epoch 19/100
# 58/58 [==============================] - 676s 12s/step - loss: 0.8427 - binary_accuracy: 0.8274 - val_loss: 0.4972 - val_binary_accuracy: 0.8859
# Epoch 20/100
# 58/58 [==============================] - 686s 12s/step - loss: 0.8188 - binary_accuracy: 0.8364 - val_loss: 0.4784 - val_binary_accuracy: 0.8783
# Epoch 21/100
# 58/58 [==============================] - 685s 12s/step - loss: 0.6965 - binary_accuracy: 0.8367 - val_loss: 0.4548 - val_binary_accuracy: 0.8935
# Epoch 22/100
# 58/58 [==============================] - 676s 12s/step - loss: 0.7440 - binary_accuracy: 0.8389 - val_loss: 0.7193 - val_binary_accuracy: 0.8348
# Epoch 23/100
# 58/58 [==============================] - 682s 12s/step - loss: 0.6366 - binary_accuracy: 0.8402 - val_loss: 0.3627 - val_binary_accuracy: 0.9000
# Epoch 24/100
# 58/58 [==============================] - 685s 12s/step - loss: 0.5203 - binary_accuracy: 0.8497 - val_loss: 0.4102 - val_binary_accuracy: 0.8870
# Epoch 25/100
# 58/58 [==============================] - 668s 12s/step - loss: 0.4741 - binary_accuracy: 0.8549 - val_loss: 0.3472 - val_binary_accuracy: 0.8978
# Epoch 26/100
# 58/58 [==============================] - 687s 12s/step - loss: 0.4052 - binary_accuracy: 0.8698 - val_loss: 0.3051 - val_binary_accuracy: 0.9033
# Epoch 27/100
# 58/58 [==============================] - 672s 12s/step - loss: 0.3673 - binary_accuracy: 0.8723 - val_loss: 0.3160 - val_binary_accuracy: 0.8902
# Epoch 28/100
# 58/58 [==============================] - 681s 12s/step - loss: 0.3390 - binary_accuracy: 0.8769 - val_loss: 0.3206 - val_binary_accuracy: 0.8989
# Epoch 29/100
# 58/58 [==============================] - 724s 13s/step - loss: 0.3618 - binary_accuracy: 0.8693 - val_loss: 0.3100 - val_binary_accuracy: 0.8902
# Epoch 30/100
# 58/58 [==============================] - 771s 13s/step - loss: 0.3431 - binary_accuracy: 0.8745 - val_loss: 0.2896 - val_binary_accuracy: 0.9043
# Epoch 31/100
# 58/58 [==============================] - 769s 13s/step - loss: 0.3142 - binary_accuracy: 0.8788 - val_loss: 0.2822 - val_binary_accuracy: 0.9098
# Epoch 32/100
# 58/58 [==============================] - 770s 13s/step - loss: 0.2964 - binary_accuracy: 0.8813 - val_loss: 0.4733 - val_binary_accuracy: 0.8511
# Epoch 33/100
# 58/58 [==============================] - 774s 13s/step - loss: 0.3135 - binary_accuracy: 0.8750 - val_loss: 0.3559 - val_binary_accuracy: 0.8891
# Epoch 34/100
# 58/58 [==============================] - 773s 13s/step - loss: 0.2760 - binary_accuracy: 0.8916 - val_loss: 0.2665 - val_binary_accuracy: 0.9174
# Epoch 35/100
# 58/58 [==============================] - 773s 13s/step - loss: 0.2804 - binary_accuracy: 0.8897 - val_loss: 0.2965 - val_binary_accuracy: 0.9065
# Epoch 36/100
# 58/58 [==============================] - 769s 13s/step - loss: 0.2745 - binary_accuracy: 0.8842 - val_loss: 0.2697 - val_binary_accuracy: 0.8978
# Epoch 37/100
# 58/58 [==============================] - 770s 13s/step - loss: 0.2551 - binary_accuracy: 0.8951 - val_loss: 0.3233 - val_binary_accuracy: 0.8978
# Epoch 38/100
# 58/58 [==============================] - 770s 13s/step - loss: 0.3278 - binary_accuracy: 0.8677 - val_loss: 0.2651 - val_binary_accuracy: 0.8989
# Epoch 39/100
# 58/58 [==============================] - 768s 13s/step - loss: 0.2583 - binary_accuracy: 0.8908 - val_loss: 0.2896 - val_binary_accuracy: 0.9022
# Epoch 40/100
# 58/58 [==============================] - 584s 10s/step - loss: 0.2564 - binary_accuracy: 0.8970 - val_loss: 0.2880 - val_binary_accuracy: 0.9087
# Epoch 41/100
# 58/58 [==============================] - 486s 8s/step - loss: 0.2380 - binary_accuracy: 0.9033 - val_loss: 0.2616 - val_binary_accuracy: 0.9141
# Epoch 42/100
# 58/58 [==============================] - 485s 8s/step - loss: 0.2478 - binary_accuracy: 0.8965 - val_loss: 0.2518 - val_binary_accuracy: 0.9141
# Epoch 43/100
# 58/58 [==============================] - 487s 8s/step - loss: 0.2338 - binary_accuracy: 0.9008 - val_loss: 0.2802 - val_binary_accuracy: 0.8902
# Epoch 44/100
# 58/58 [==============================] - 479s 8s/step - loss: 0.2487 - binary_accuracy: 0.8984 - val_loss: 0.2483 - val_binary_accuracy: 0.9163
# Epoch 45/100
# 58/58 [==============================] - 479s 8s/step - loss: 0.2394 - binary_accuracy: 0.8984 - val_loss: 0.5341 - val_binary_accuracy: 0.8304
# Epoch 46/100
# 58/58 [==============================] - 482s 8s/step - loss: 0.2477 - binary_accuracy: 0.8973 - val_loss: 0.3336 - val_binary_accuracy: 0.8946
# Epoch 47/100
# 58/58 [==============================] - 468s 8s/step - loss: 0.2408 - binary_accuracy: 0.9008 - val_loss: 0.2550 - val_binary_accuracy: 0.9141
# Epoch 48/100
# 58/58 [==============================] - 477s 8s/step - loss: 0.2411 - binary_accuracy: 0.9000 - val_loss: 0.4361 - val_binary_accuracy: 0.8609
# Epoch 49/100
# 58/58 [==============================] - 480s 8s/step - loss: 0.2623 - binary_accuracy: 0.8957 - val_loss: 0.2543 - val_binary_accuracy: 0.9087

# %%
history_2.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
plt.plot(history_2.history['loss'][1:])
plt.plot(history_2.history['val_loss'][1:])
plt.legend(['train', 'valid'])
plt.show();

# %%
plt.plot(history_2.history['binary_accuracy'][1:])
plt.plot(history_2.history['val_binary_accuracy'][1:])
plt.legend(['train', 'valid'])
plt.show();

# %% [markdown]
# ### Classification accuracy

# %%
x_val_2, y_val_2 = list(tfds.as_numpy(ds_val))[0]
y_pred_2 = model_2.predict(x_val_2)
sum((y_pred_2[:, 0] > 0) == y_val_2) / len(y_val_2)
# Out:
# 0.90625

# %%
plt.figure(figsize=(16, 16))
plt.subplots_adjust(hspace=0.4, wspace=.2)

for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(x_val_2[i].astype('int32'))
    
    real_y = 'healthy' if y_val_2[i] == 1 else 'tumor'
    pred_y = 'healthy' if y_pred_2[i] > 0 else 'tumor'
    
    plt.title(f'Real class: {real_y}\n Prediction: {pred_y}')
    plt.axis('off')

plt.show();

# %%
y_pred_2_binary = [1 if y > 0 else 0 for y in y_pred_2]

# %%
cf = tf.math.confusion_matrix(y_val_2, y_pred_2_binary, dtype=tf.dtypes.int32)
sns.heatmap(cf, annot=True)
plt.xlabel('Predictions')
plt.ylabel('True values')
plt.show();

# %%
print(classification_report(y_val_2, y_pred_2_binary, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#  Brain Tumor       0.88      0.97      0.92        36
#      Healthy       0.96      0.82      0.88        28
#
#     accuracy                           0.91        64
#    macro avg       0.92      0.90      0.90        64
# weighted avg       0.91      0.91      0.91        64

# %% [markdown]
# ## Mobilenet_v2 - dropout increase

# %%
input_shape = (224, 224, 3)

# %%
resizer = lambda x, y: (tf.image.resize(x, input_shape[:2]), y)

ds_train_reshaped = ds_train.map(resizer)
ds_val_reshaped = ds_val.map(resizer)

# %%
for image_batch, labels_batch in ds_train_reshaped:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
base_model = keras.applications.mobilenet_v2.MobileNetV2(
    weights='imagenet',
    input_shape=input_shape,
    include_top=False
)

base_model.trainable = False

model_3 = tf.keras.Sequential(
    [
        keras.layers.Input(input_shape, dtype=tf.float32),
        base_model,
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dense(320),
        keras.layers.Dropout(0.4, seed=404),
        keras.layers.Dense(64),
        keras.layers.Dropout(0.4, seed=404),
        keras.layers.Dense(1)
    ],
    name='mobilenet_with_2_dense_dropout_increase'
)

model_3.summary()
# Out:
# Model: "mobilenet_with_2_dense_dropout_increase"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1280)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 320)               409920
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 320)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                20544
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,688,513
# Trainable params: 430,529
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model_3.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

# %%
epochs = 100
patience = 5

# %%
history_3 = model_3.fit(
    ds_train_reshaped,
    epochs=epochs,
    validation_data=ds_val_reshaped,
    callbacks=[keras.callbacks.EarlyStopping(patience=patience)]
)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 195s 3s/step - loss: 0.6811 - binary_accuracy: 0.7832 - val_loss: 0.3097 - val_binary_accuracy: 0.8783
# Epoch 2/100
# 58/58 [==============================] - 186s 3s/step - loss: 0.4238 - binary_accuracy: 0.8486 - val_loss: 0.2783 - val_binary_accuracy: 0.9000
# Epoch 3/100
# 58/58 [==============================] - 183s 3s/step - loss: 0.3568 - binary_accuracy: 0.8715 - val_loss: 0.2497 - val_binary_accuracy: 0.8924
# Epoch 4/100
# 58/58 [==============================] - 193s 3s/step - loss: 0.3230 - binary_accuracy: 0.8856 - val_loss: 0.2319 - val_binary_accuracy: 0.9109
# Epoch 5/100
# 58/58 [==============================] - 180s 3s/step - loss: 0.2790 - binary_accuracy: 0.8959 - val_loss: 0.2608 - val_binary_accuracy: 0.9087
# Epoch 6/100
# 58/58 [==============================] - 188s 3s/step - loss: 0.2559 - binary_accuracy: 0.9084 - val_loss: 0.2027 - val_binary_accuracy: 0.9293
# Epoch 7/100
# 58/58 [==============================] - 190s 3s/step - loss: 0.2392 - binary_accuracy: 0.9168 - val_loss: 0.2137 - val_binary_accuracy: 0.9272
# Epoch 8/100
# 58/58 [==============================] - 183s 3s/step - loss: 0.2167 - binary_accuracy: 0.9174 - val_loss: 0.2063 - val_binary_accuracy: 0.9141
# Epoch 9/100
# 58/58 [==============================] - 191s 3s/step - loss: 0.2205 - binary_accuracy: 0.9166 - val_loss: 0.3302 - val_binary_accuracy: 0.8663
# Epoch 10/100
# 58/58 [==============================] - 185s 3s/step - loss: 0.2237 - binary_accuracy: 0.9212 - val_loss: 0.1766 - val_binary_accuracy: 0.9293
# Epoch 11/100
# 58/58 [==============================] - 184s 3s/step - loss: 0.1890 - binary_accuracy: 0.9293 - val_loss: 0.1727 - val_binary_accuracy: 0.9391
# Epoch 12/100
# 58/58 [==============================] - 194s 3s/step - loss: 0.1553 - binary_accuracy: 0.9372 - val_loss: 0.1757 - val_binary_accuracy: 0.9326
# Epoch 13/100
# 58/58 [==============================] - 186s 3s/step - loss: 0.1505 - binary_accuracy: 0.9413 - val_loss: 0.1915 - val_binary_accuracy: 0.9207
# Epoch 14/100
# 58/58 [==============================] - 191s 3s/step - loss: 0.1498 - binary_accuracy: 0.9427 - val_loss: 0.1968 - val_binary_accuracy: 0.9380
# Epoch 15/100
# 58/58 [==============================] - 190s 3s/step - loss: 0.1501 - binary_accuracy: 0.9391 - val_loss: 0.1655 - val_binary_accuracy: 0.9380
# Epoch 16/100
# 58/58 [==============================] - 182s 3s/step - loss: 0.1435 - binary_accuracy: 0.9432 - val_loss: 0.1714 - val_binary_accuracy: 0.9359
# Epoch 17/100
# 58/58 [==============================] - 194s 3s/step - loss: 0.1218 - binary_accuracy: 0.9543 - val_loss: 0.2090 - val_binary_accuracy: 0.9315
# Epoch 18/100
# 58/58 [==============================] - 181s 3s/step - loss: 0.1205 - binary_accuracy: 0.9543 - val_loss: 0.1584 - val_binary_accuracy: 0.9467
# Epoch 19/100
# 58/58 [==============================] - 178s 3s/step - loss: 0.1142 - binary_accuracy: 0.9560 - val_loss: 0.2193 - val_binary_accuracy: 0.9261
# Epoch 20/100
# 58/58 [==============================] - 187s 3s/step - loss: 0.1144 - binary_accuracy: 0.9565 - val_loss: 0.1600 - val_binary_accuracy: 0.9359
# Epoch 21/100
# 58/58 [==============================] - 177s 3s/step - loss: 0.1030 - binary_accuracy: 0.9601 - val_loss: 0.2142 - val_binary_accuracy: 0.9326
# Epoch 22/100
# 58/58 [==============================] - 188s 3s/step - loss: 0.0875 - binary_accuracy: 0.9622 - val_loss: 0.1576 - val_binary_accuracy: 0.9402
# Epoch 23/100
# 58/58 [==============================] - 178s 3s/step - loss: 0.1285 - binary_accuracy: 0.9497 - val_loss: 0.1891 - val_binary_accuracy: 0.9326
# Epoch 24/100
# 58/58 [==============================] - 180s 3s/step - loss: 0.1170 - binary_accuracy: 0.9549 - val_loss: 0.1642 - val_binary_accuracy: 0.9424
# Epoch 25/100
# 58/58 [==============================] - 182s 3s/step - loss: 0.0776 - binary_accuracy: 0.9728 - val_loss: 0.1496 - val_binary_accuracy: 0.9478
# Epoch 26/100
# 58/58 [==============================] - 181s 3s/step - loss: 0.0829 - binary_accuracy: 0.9677 - val_loss: 0.1586 - val_binary_accuracy: 0.9478
# Epoch 27/100
# 58/58 [==============================] - 179s 3s/step - loss: 0.0984 - binary_accuracy: 0.9598 - val_loss: 0.1575 - val_binary_accuracy: 0.9380
# Epoch 28/100
# 58/58 [==============================] - 190s 3s/step - loss: 0.0862 - binary_accuracy: 0.9668 - val_loss: 0.1664 - val_binary_accuracy: 0.9533
# Epoch 29/100
# 58/58 [==============================] - 167s 3s/step - loss: 0.0841 - binary_accuracy: 0.9649 - val_loss: 0.2025 - val_binary_accuracy: 0.9446
# Epoch 30/100
# 58/58 [==============================] - 186s 3s/step - loss: 0.1375 - binary_accuracy: 0.9516 - val_loss: 0.1642 - val_binary_accuracy: 0.9326

# %%
history_3.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
plt.plot(history_3.history['loss'][1:])
plt.plot(history_3.history['val_loss'][1:])
plt.legend(['train', 'valid'])
plt.show();

# %%
plt.plot(history_3.history['binary_accuracy'][1:])
plt.plot(history_3.history['val_binary_accuracy'][1:])
plt.legend(['train', 'valid'])
plt.show();

# %% [markdown]
# ### Classification accuracy

# %%
x_val_3, y_val_3 = list(tfds.as_numpy(ds_val_reshaped))[0]
y_pred_3 = model_3.predict(x_val_3)
sum((y_pred_3[:, 0] > 0) == y_val_3) / len(y_val_3)
# Out:
# 0.953125

# %%
plt.figure(figsize=(16, 16))
plt.subplots_adjust(hspace=0.4, wspace=.2)

for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(x_val_3[i].astype('int32'))
    
    real_y = 'healthy' if y_val_3[i] == 1 else 'tumor'
    pred_y = 'healthy' if y_pred_3[i] > 0 else 'tumor'
    
    plt.title(f'Real class: {real_y}\n Prediction: {pred_y}')
    plt.axis('off')

plt.show();

# %%
y_pred_3_binary = [1 if y > 0 else 0 for y in y_pred_3]

# %%
cf = tf.math.confusion_matrix(y_val_3, y_pred_3_binary, dtype=tf.dtypes.int32)
sns.heatmap(cf, annot=True)
plt.xlabel('Predictions')
plt.ylabel('True values')
plt.show();

# %%
print(classification_report(y_val_3, y_pred_3_binary, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#  Brain Tumor       0.94      0.97      0.96        33
#      Healthy       0.97      0.94      0.95        31
#
#     accuracy                           0.95        64
#    macro avg       0.95      0.95      0.95        64
# weighted avg       0.95      0.95      0.95        64

# %% [markdown]
# ## Inception_v3 - dropout increase

# %%
input_shape = (256, 256, 3)

# %%
base_model = keras.applications.inception_v3.InceptionV3(
    weights='imagenet',
    input_shape=input_shape,
    include_top=False
)

base_model.trainable = False

model_4 = tf.keras.Sequential(
    [
        keras.layers.Input(input_shape, dtype=tf.float32),
        base_model,
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dense(320),
        keras.layers.Dropout(0.4, seed=404),
        keras.layers.Dense(64),
        keras.layers.Dropout(0.4, seed=404),
        keras.layers.Dense(1)
    ],
    name='inception_with_2_dense_dropout_increase'
)

model_4.summary()
# Out:
# Model: "inception_with_2_dense_dropout_increase"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 6, 6, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 320)               655680
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 320)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                20544
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 22,479,073
# Trainable params: 676,289
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_4.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

# %%
epochs = 100
patience = 5

# %%
history_4 = model_4.fit(
    ds_train,
    epochs=epochs,
    validation_data=ds_val,
    callbacks=[keras.callbacks.EarlyStopping(patience=patience)]
)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 467s 8s/step - loss: 16.0287 - binary_accuracy: 0.6000 - val_loss: 12.5708 - val_binary_accuracy: 0.5424
# Epoch 2/100
# 58/58 [==============================] - 458s 8s/step - loss: 10.7464 - binary_accuracy: 0.6639 - val_loss: 3.6323 - val_binary_accuracy: 0.7793
# Epoch 3/100
# 58/58 [==============================] - 467s 8s/step - loss: 7.7962 - binary_accuracy: 0.6859 - val_loss: 3.1476 - val_binary_accuracy: 0.7685
# Epoch 4/100
# 58/58 [==============================] - 466s 8s/step - loss: 7.1351 - binary_accuracy: 0.7005 - val_loss: 4.9286 - val_binary_accuracy: 0.7250
# Epoch 5/100
# 58/58 [==============================] - 461s 8s/step - loss: 5.8074 - binary_accuracy: 0.7253 - val_loss: 2.3310 - val_binary_accuracy: 0.8065
# Epoch 6/100
# 58/58 [==============================] - 477s 8s/step - loss: 5.2720 - binary_accuracy: 0.7380 - val_loss: 5.8594 - val_binary_accuracy: 0.6761
# Epoch 7/100
# 58/58 [==============================] - 477s 8s/step - loss: 5.3585 - binary_accuracy: 0.7283 - val_loss: 3.5417 - val_binary_accuracy: 0.7511
# Epoch 8/100
# 58/58 [==============================] - 470s 8s/step - loss: 3.6871 - binary_accuracy: 0.7609 - val_loss: 1.2466 - val_binary_accuracy: 0.8717
# Epoch 9/100
# 58/58 [==============================] - 467s 8s/step - loss: 3.1722 - binary_accuracy: 0.7696 - val_loss: 2.1374 - val_binary_accuracy: 0.7957
# Epoch 10/100
# 58/58 [==============================] - 470s 8s/step - loss: 2.7799 - binary_accuracy: 0.7712 - val_loss: 0.8771 - val_binary_accuracy: 0.8761
# Epoch 11/100
# 58/58 [==============================] - 472s 8s/step - loss: 2.0364 - binary_accuracy: 0.7899 - val_loss: 1.8544 - val_binary_accuracy: 0.7902
# Epoch 12/100
# 58/58 [==============================] - 471s 8s/step - loss: 2.0780 - binary_accuracy: 0.7910 - val_loss: 0.7488 - val_binary_accuracy: 0.8728
# Epoch 13/100
# 58/58 [==============================] - 471s 8s/step - loss: 1.5948 - binary_accuracy: 0.8027 - val_loss: 0.9111 - val_binary_accuracy: 0.8543
# Epoch 14/100
# 58/58 [==============================] - 472s 8s/step - loss: 1.3868 - binary_accuracy: 0.8106 - val_loss: 0.5672 - val_binary_accuracy: 0.8913
# Epoch 15/100
# 58/58 [==============================] - 466s 8s/step - loss: 1.1042 - binary_accuracy: 0.8212 - val_loss: 0.5976 - val_binary_accuracy: 0.8707
# Epoch 16/100
# 58/58 [==============================] - 468s 8s/step - loss: 1.0703 - binary_accuracy: 0.8185 - val_loss: 0.4815 - val_binary_accuracy: 0.8935
# Epoch 17/100
# 58/58 [==============================] - 462s 8s/step - loss: 0.8290 - binary_accuracy: 0.8266 - val_loss: 0.9033 - val_binary_accuracy: 0.8022
# Epoch 18/100
# 58/58 [==============================] - 478s 8s/step - loss: 0.6986 - binary_accuracy: 0.8299 - val_loss: 0.4336 - val_binary_accuracy: 0.8739
# Epoch 19/100
# 58/58 [==============================] - 474s 8s/step - loss: 0.6559 - binary_accuracy: 0.8288 - val_loss: 0.3986 - val_binary_accuracy: 0.8804
# Epoch 20/100
# 58/58 [==============================] - 472s 8s/step - loss: 0.5113 - binary_accuracy: 0.8473 - val_loss: 0.3251 - val_binary_accuracy: 0.9022
# Epoch 21/100
# 58/58 [==============================] - 473s 8s/step - loss: 0.4554 - binary_accuracy: 0.8476 - val_loss: 0.4150 - val_binary_accuracy: 0.8380
# Epoch 22/100
# 58/58 [==============================] - 487s 8s/step - loss: 0.4176 - binary_accuracy: 0.8470 - val_loss: 0.2934 - val_binary_accuracy: 0.9011
# Epoch 23/100
# 58/58 [==============================] - 481s 8s/step - loss: 0.3927 - binary_accuracy: 0.8503 - val_loss: 0.2818 - val_binary_accuracy: 0.8946
# Epoch 24/100
# 58/58 [==============================] - 475s 8s/step - loss: 0.3375 - binary_accuracy: 0.8690 - val_loss: 0.2813 - val_binary_accuracy: 0.9022
# Epoch 25/100
# 58/58 [==============================] - 404s 7s/step - loss: 0.3341 - binary_accuracy: 0.8584 - val_loss: 0.2902 - val_binary_accuracy: 0.9000
# Epoch 26/100
# 58/58 [==============================] - 306s 5s/step - loss: 0.3312 - binary_accuracy: 0.8644 - val_loss: 0.2786 - val_binary_accuracy: 0.8935
# Epoch 27/100
# 58/58 [==============================] - 298s 5s/step - loss: 0.3005 - binary_accuracy: 0.8715 - val_loss: 0.2754 - val_binary_accuracy: 0.8967
# Epoch 28/100
# 58/58 [==============================] - 241s 4s/step - loss: 0.3070 - binary_accuracy: 0.8769 - val_loss: 0.3339 - val_binary_accuracy: 0.8880
# Epoch 29/100
# 58/58 [==============================] - 282s 5s/step - loss: 0.3045 - binary_accuracy: 0.8717 - val_loss: 0.2753 - val_binary_accuracy: 0.9043
# Epoch 30/100
# 58/58 [==============================] - 298s 5s/step - loss: 0.3038 - binary_accuracy: 0.8726 - val_loss: 0.2698 - val_binary_accuracy: 0.9033
# Epoch 31/100
# 58/58 [==============================] - 294s 5s/step - loss: 0.2904 - binary_accuracy: 0.8818 - val_loss: 0.2979 - val_binary_accuracy: 0.9000
# Epoch 32/100
# 58/58 [==============================] - 305s 5s/step - loss: 0.2970 - binary_accuracy: 0.8747 - val_loss: 0.3271 - val_binary_accuracy: 0.8902
# Epoch 33/100
# 58/58 [==============================] - 306s 5s/step - loss: 0.2893 - binary_accuracy: 0.8791 - val_loss: 0.2667 - val_binary_accuracy: 0.9000
# Epoch 34/100
# 58/58 [==============================] - 301s 5s/step - loss: 0.2870 - binary_accuracy: 0.8793 - val_loss: 0.2768 - val_binary_accuracy: 0.9054
# Epoch 35/100
# 58/58 [==============================] - 292s 5s/step - loss: 0.2838 - binary_accuracy: 0.8815 - val_loss: 0.2638 - val_binary_accuracy: 0.8989
# Epoch 36/100
# 58/58 [==============================] - 302s 5s/step - loss: 0.2752 - binary_accuracy: 0.8867 - val_loss: 0.2693 - val_binary_accuracy: 0.9065
# Epoch 37/100
# 58/58 [==============================] - 304s 5s/step - loss: 0.2690 - binary_accuracy: 0.8853 - val_loss: 0.2634 - val_binary_accuracy: 0.9022
# Epoch 38/100
# 58/58 [==============================] - 304s 5s/step - loss: 0.2854 - binary_accuracy: 0.8837 - val_loss: 0.2591 - val_binary_accuracy: 0.9098
# Epoch 39/100
# 58/58 [==============================] - 287s 5s/step - loss: 0.2635 - binary_accuracy: 0.8878 - val_loss: 0.2725 - val_binary_accuracy: 0.9065
# Epoch 40/100
# 58/58 [==============================] - 300s 5s/step - loss: 0.3007 - binary_accuracy: 0.8693 - val_loss: 0.2766 - val_binary_accuracy: 0.8804
# Epoch 41/100
# 58/58 [==============================] - 308s 5s/step - loss: 0.2772 - binary_accuracy: 0.8848 - val_loss: 0.2699 - val_binary_accuracy: 0.9065
# Epoch 42/100
# 58/58 [==============================] - 305s 5s/step - loss: 0.2640 - binary_accuracy: 0.8918 - val_loss: 0.2919 - val_binary_accuracy: 0.9043
# Epoch 43/100
# 58/58 [==============================] - 276s 5s/step - loss: 0.2596 - binary_accuracy: 0.8954 - val_loss: 0.2725 - val_binary_accuracy: 0.9098

# %%
history_4.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
plt.plot(history_4.history['loss'][1:])
plt.plot(history_4.history['val_loss'][1:])
plt.legend(['train', 'valid'])
plt.show();

# %%
plt.plot(history_4.history['binary_accuracy'][1:])
plt.plot(history_4.history['val_binary_accuracy'][1:])
plt.legend(['train', 'valid'])
plt.show();

# %% [markdown]
# ### Classification accuracy

# %%
x_val_4, y_val_4 = list(tfds.as_numpy(ds_val))[0]
y_pred_4 = model_4.predict(x_val_4)
sum((y_pred_4[:, 0] > 0) == y_val_4) / len(y_val_4)
# Out:
# 0.875

# %%
plt.figure(figsize=(16, 16))
plt.subplots_adjust(hspace=0.4, wspace=.2)

for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(x_val_4[i].astype('int32'))
    
    real_y = 'healthy' if y_val_4[i] == 1 else 'tumor'
    pred_y = 'healthy' if y_pred_4[i] > 0 else 'tumor'
    
    plt.title(f'Real class: {real_y}\n Prediction: {pred_y}')
    plt.axis('off')

plt.show();

# %%
y_pred_4_binary = [1 if y > 0 else 0 for y in y_pred_4]

# %%
cf = tf.math.confusion_matrix(y_val_4, y_pred_4_binary, dtype=tf.dtypes.int32)
sns.heatmap(cf, annot=True)
plt.xlabel('Predictions')
plt.ylabel('True values')
plt.show();

# %%
print(classification_report(y_val_4, y_pred_4_binary, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#  Brain Tumor       0.84      0.94      0.89        34
#      Healthy       0.92      0.80      0.86        30
#
#     accuracy                           0.88        64
#    macro avg       0.88      0.87      0.87        64
# weighted avg       0.88      0.88      0.87        64
